# %% [markdown]
# ## Backtesting via https://github.com/kernc/backtesting.py

# %%
from backtesting_safe_strategy import calculate
bt, stats, heatmap = calculate()
heatmap.sort_values().iloc[-10:]
# Out:
# /Users/i.novikov/MyProjects/venv_jupyter_lab/lib/python3.8/site-packages/backtesting/_plotting.py:45: UserWarning: Jupyter Notebook detected. Setting Bokeh output to notebook. This may not work in Jupyter clients without JavaScript support (e.g. PyCharm, Spyder IDE). Reset with `backtesting.set_bokeh_output(notebook=False)`.
#   warnings.warn('Jupyter Notebook detected. '
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
# /Users/i.novikov/MyProjects/venv_jupyter_lab/lib/python3.8/site-packages/backtesting/backtesting.py:1472: UserWarning: Searching for best of 496 configurations.
#   output = _optimize_grid()
# /Users/i.novikov/MyProjects/venv_jupyter_lab/lib/python3.8/site-packages/backtesting/backtesting.py:1361: UserWarning: For multiprocessing support in `Backtest.optimize()` set multiprocessing start method to 'fork'.
# ...

# %%
heatmap.sort_values().iloc[-10:]
# Out:
# buy_after_decrease_percents  sell_after_profit_percents  re_buy_percents
# 90                           80                          15                 27523.126355
# 40                           90                          20                 27937.573326
# 50                           90                          20                 27985.733054
# 60                           90                          25                 27999.214794
# 10                           90                          20                 28411.323212
#                                                          25                 28691.635340
# 50                           90                          25                 28723.641470
# 60                           90                          20                 28881.229541
# 70                           90                          20                 28881.684073
# 80                           90                          20                 29521.240235
# ...

# %%
print(stats)
bt.plot()
plot_heatmaps(heatmap, agg='mean')
# Out:
# Start                     2000-01-03 00:00:00
# End                       2015-12-31 00:00:00
# Duration                   5841 days 00:00:00
# Exposure Time [%]                   92.372671
# Equity Final [$]                 127424.61843
# Equity Peak [$]                 130007.578025
# Return [%]                        1174.246184
# Buy & Hold Return [%]             2532.969299
# Return (Ann.) [%]                   17.273117
# Volatility (Ann.) [%]               34.989532
# Sharpe Ratio                         0.493665
# Sortino Ratio                        0.887851
# Calmar Ratio                         0.330075
# Max. Drawdown [%]                  -52.330958
# Avg. Drawdown [%]                   -2.210547
# Max. Drawdown Duration     1286 days 00:00:00
# Avg. Drawdown Duration       26 days 00:00:00
# # Trades                                  409
# Win Rate [%]                        97.799511
# Best Trade [%]                     210.534104
# ...
